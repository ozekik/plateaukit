# %% [markdown]
# # 範囲の選択と抽出
#
# ### データの読み込み
#
# PLATEAUデータの読み込みについては[データセットの読み込みと利用](/plateaukit/library/dataset/)を参照してください。

# %%
from plateaukit import load_dataset

# データの読み込み
tokyo23ku = load_dataset("plateau-tokyo23ku-2022")

# %% [markdown]
# ### 範囲の選択
#
# 読み込んだデータセットから範囲を取得するには、いくつかの方法が利用可能です。
#
# - **`get_area()`** : 全範囲を選択します。
# - **`area_from_bbox(bbox)`** : 範囲を `[左上のx座標 (経度), 左上のy座標 (緯度), 右下のx座標 (経度), 右下のy座標 (緯度)]` で指定します。
# - **`area_from_points(point, size=[width, height])`** : 範囲を一つ以上の地点の座標と範囲のサイズで指定します。
# - **`area_from_postcode(postcode)`** : 範囲を郵便番号で指定します。
# - **`area_from_address(address)`** : 範囲を住所で指定します。
# - **`area_from_landmark(landmark)`** : 範囲を建物等のランドマークの名前から指定します。

# %%
# 住所から範囲を取得
area = tokyo23ku.area_from_address("東京都新宿区西新宿2-8-1")

area
# Out:
# Area()

# %% [markdown]
# ### 範囲のプレビュー
#
# `.show()` メソッドを使って選択範囲をプレビューできます。
#
# - スクリプトとして実行している場合はブラウザで表示されます。

# %%
area.show()
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 35.69012600000001,
#     &quot;longitude&quot;: 139.693064,
#     &quot;pitch&quot;: 45,
#     &quot;zoom&quot;: 14
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;GeoJsonLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;buildingId&quot;: &quot;13104-bldg-7859&quot;,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.687475,
#                   35.69145
#                 ],
#                 [
#                   139.68756,
#                   35.691476
#                 ],
#                 [
#                   139.687532,
#                   35.691538
#                 ],
#                 [
#                   139.687529,
#                   35.691537
#                 ],
#                 [
#                   139.687523,
#                   35.691551
#                 ],
#                 [
#                   139.687518,
#                   35.69155
#                 ],
#                 [
#                   139.687512,
#                   35.691563
#                 ],
#                 [
#                   139.687436,
#                   35.69154
#                 ],
#                 [
#                   139.687442,
#                   35.691526
#                 ],
#                 [
#                   139.687439,
#                   35.691525
#                 ],
#                 [
#                   139.687454,
#                   35.691494
#                 ],
#                 [
#                   139.687455,
#                   35.691495
#                 ],
#                 [
#                   139.687475,
#                   35.69145
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;latitude&quot;: 35.69150682752363,
#           &quot;longitude&quot;: 139.6874967006076,
#           &quot;measuredHeight&quot;: 11.6,
#           &quot;name&quot;: null,
#           &quot;type&quot;: &quot;Building&quot;
#         },
#         {
#           &quot;buildingId&quot;: &quot;13104-bldg-7845&quot;,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.687394,
#                   35.691441
#                 ],
#                 [
#                   139.687457,
#                   35.691461
#                 ],
#                 [
#                   139.687428,
#                   35.691523
#                 ],
#                 [
#                   139.687366,
#                   35.691504
#                 ],
#                 [
#                   139.687366,
#                   35.691503
#                 ],
#                 [
#                   139.687352,
#                   35.691501
#                 ],
#                 [
#                   139.687341,
#                   35.691507
#                 ],
#                 [
#                   139.687319,
#                   35.691506
#                 ],
#                 [
#                   139.687334,
#                   35.691474
#                 ],
#                 [
#                   139.687325,
#                   35.691471
#                 ],
#                 [
#                   139.687349,
#                   35.691419
#                 ],
#                 [
#                   139.687397,
#                   35.691434
#                 ],
#                 [
#                   139.687394,
#                   35.691441
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;latitude&quot;: 35.69147341773958,
#           &quot;longitude&quot;: 139.6873854848515,
#           &quot;measuredHeight&quot;: 17.1,
#           &quot;name&quot;: null,
#           &quot;type&quot;: &quot;Building&quot;
#         },
#         {
#           &quot;buildingId&quot;: &quot;13104-bldg-7963&quot;,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.687407,
#                   35.691554
#                 ],
#                 [
#                   139.687455,
#                   35.69157
#                 ],
#                 [
#                   139.687426,
#                   35.691667
#                 ],
#                 [
#                   139.687285,
#                   35.691636
#                 ],
#                 [
#                   139.687316,
#                   35.691537
#                 ],
#                 [
#                   139.687407,
#                   35.691554
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;latitude&quot;: 35.69160147112961,
#           &quot;longitude&quot;: 139.6873706826706,
#           &quot;measuredHeight&quot;: 21.6,
#           &quot;name&quot;: null,
#           &quot;type&quot;: &quot;Building&quot;
#         },
#         {
#           &quot;buildingId&quot;: &quot;13104-bldg-6456&quot;,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.687356,
#                   35.690204
#                 ],
#                 [
#                   139.68732,
#                   35.690251
#                 ],
#                 [
#                   139.687237,
#                   35.69021
#                 ],
#                 [
#                   139.687278,
#                   35.690156
#                 ],
#                 [
#                   139.687323,
#                   35.690178
#                 ],
#                 [
#                   139.687318,
#                   35.690185
#                 ],
#                 [
#                   139.687356,
#                   35.690204
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;latitude&quot;: 35.69020425229999,
#           &quot;longitude&quot;: 139.68729659141147,
#           &quot;measuredHeight&quot;: 7.6,
#           &quot;name&quot;: null,
#           &quot;type&quot;: &quot;Building&quot;
#         },
#         {
#           &quot;buildingId&quot;: &quot;13104-bldg-4642&quot;,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.687324,
#                   35.68871
#                 ],
#                 [
#                   139.687298,
#                   35.688776
#                 ],
#                 [
#                   139.687194,
#                   35.688749
#                 ],
#                 [
#                   139.68722,
#                   35.688683
#                 ],
#                 [
#                   139.687324,
#                   35.68871
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;latitude&quot;: 35.68872950000

# %% [markdown]
# ### 選択範囲のデータを取得
#
# `.gdf` プロパティから選択範囲のデータ (`geopandas.GeoDataFrame`) を取得できます。

# %%
area.gdf
# Out:
#              buildingId  measuredHeight          name      type   longitude  \
# 19070   13104-bldg-7859            11.6          None  Building  139.687497
# 19072   13104-bldg-7845            17.1          None  Building  139.687385
# 19073   13104-bldg-7963            21.6          None  Building  139.687371
# 19226   13104-bldg-6456             7.6          None  Building  139.687297
# 19368   13104-bldg-4642             9.5          None  Building  139.687259
# ...                 ...             ...           ...       ...         ...
# 56483  13104-bldg-11151            32.1          None  Building  139.692667
# 56484   13104-bldg-8242             3.0          None  Building  139.687557
# 56494  13104-bldg-10881            13.3          None  Building  139.693556
# 56496   13104-bldg-9998             4.2          None  Building  139.696075
# 56499  13104-bldg-10498           133.3  関東信越厚生局東京事務所  Building  139.687721
#
#         latitude                                           geometry
# 19070  35.691507  POLYGON ((139.68748 35.69145, 139.68756 35.691...
# 19072  35.691473  POLYGON ((139.68739 35.69144, 139.68746 35.691...
# 19073  35.691601  POLYGON ((139.68741 35.69155, 139.68745 35.691...
# 19226  35.690204  POLYGON ((139.68736 35.69020, 139.68732 35.690...
# 19368  35.688730  POLYGON ((139.68732 35.68871, 139.68730 35.688...
# ...          ...                                                ...
# 56483  35.694708  POLYGON ((139.69274 35.69477, 139.69268 35.694...
# 56484  35.691978  POLYGON ((139.68757 35.69202, 139.68754 35.692...
# 56494  35.694538  POLYGON ((139.69351 35.69447, 139.69357 35.694...
# 56496  35.693910  POLYGON ((139.69605 35.69393, 139.69604 35.693...
# 56499  35.694073  POLYGON ((139.68792 35.69406, 139.68796 35.694...
#
# [984 rows x 7 columns]

# %% [markdown]
# ### GeoJSON への変換
#
# `.to_geojson()` メソッドを使って選択範囲を GeoJSON 形式に変換できます。

# %%
data = area.to_geojson()

data[:300]
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "19070", "type": "Feature", "properties": {"buildingId": "13104-bldg-7859", "measuredHeight": 11.6, "name": null, "type": "Building", "longitude": 139.6874967006076, "latitude": 35.69150682752363}, "geometry": {"type": "Polygon", "coordinates": [[[13'
