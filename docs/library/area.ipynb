# %% [markdown]
# # 範囲の選択と抽出
#
# PLATEAUデータの読み込みについては[データセットの読み込みと利用](/plateaukit/library/dataset/)を参照してください。

# %% [markdown]
# ### 範囲の選択
#
# `.get_area()` メソッドを使って範囲を選択します。
#
# - 引数は `[左上のx座標 (経度), 左上のy座標 (緯度), 右下のx座標 (経度), 右下のy座標 (緯度)]` で指定します。
# - 引数を指定しない場合は全範囲が選択されます。

# %%
from plateaukit import load_dataset

tokyo23ku = load_dataset("plateau-tokyo23ku")

# %% [markdown]
# `plateaukit.geocoding` モジュールを使って住所などから座標を取得することもできます。

# %%
from plateaukit import geocoding

bbox = geocoding.bbox_from_address("東京都千代田区丸の内1丁目")

bbox
# Out:
# [139.7627094235794, 35.67791153801253, 139.77393836463088, 35.687032380187915]

# %%
area = tokyo23ku.get_area([139.7627094235794, 35.67791153801253, 139.77393836463088, 35.687032380187915])

area
# Out:
# Area()

# %% [markdown]
# ### 範囲のプレビュー
#
# `.show()` メソッドを使って選択範囲をプレビューできます。
#
# - スクリプトの場合はブラウザで表示されます。

# %%
area.show()
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 35.682311999999996,
#     &quot;longitude&quot;: 139.7684135,
#     &quot;pitch&quot;: 45,
#     &quot;zoom&quot;: 14
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;GeoJsonLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.762267,
#                   35.679862
#                 ],
#                 [
#                   139.762228,
#                   35.679746
#                 ],
#                 [
#                   139.762602,
#                   35.679663
#                 ],
#                 [
#                   139.762894,
#                   35.680545
#                 ],
#                 [
#                   139.762648,
#                   35.680599
#                 ],
#                 [
#                   139.76252,
#                   35.680627
#                 ],
#                 [
#                   139.762457,
#                   35.680436
#                 ],
#                 [
#                   139.762468,
#                   35.680434
#                 ],
#                 [
#                   139.762461,
#                   35.680411
#                 ],
#                 [
#                   139.762486,
#                   35.680405
#                 ],
#                 [
#                   139.762333,
#                   35.679944
#                 ],
#                 [
#                   139.762308,
#                   35.67995
#                 ],
#                 [
#                   139.7623,
#                   35.679927
#                 ],
#                 [
#                   139.762294,
#                   35.679928
#                 ],
#                 [
#                   139.762279,
#                   35.679931
#                 ],
#                 [
#                   139.762256,
#                   35.679864
#                 ],
#                 [
#                   139.762267,
#                   35.679862
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;id&quot;: &quot;BLD_e2b1abb9-a3fa-4937-98a1-cb1b6c195069&quot;,
#           &quot;measuredHeight&quot;: 46.0
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.770271,
#                   35.678089
#                 ],
#                 [
#                   139.770309,
#                   35.678073
#                 ],
#                 [
#                   139.770314,
#                   35.678081
#                 ],
#                 [
#                   139.770325,
#                   35.678097
#                 ],
#                 [
#                   139.770334,
#                   35.678111
#                 ],
#                 [
#                   139.770386,
#                   35.678191
#                 ],
#                 [
#                   139.770314,
#                   35.67822
#                 ],
#                 [
#                   139.770313,
#                   35.678218
#                 ],
#                 [
#                   139.770266,
#                   35.678145
#                 ],
#                 [
#                   139.770264,
#                   35.678146
#                 ],
#                 [
#                   139.770249,
#                   35.678123
#                 ],
#                 [
#                   139.770281,
#                   35.678109
#                 ],
#                 [
#                   139.770274,
#                   35.678098
#                 ],
#                 [
#                   139.770276,
#                   35.678097
#                 ],
#                 [
#                   139.770271,
#                   35.678089
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;id&quot;: &quot;BLD_fcc3ba97-3eb2-4148-b153-5c13ec3b966a&quot;,
#           &quot;measuredHeight&quot;: 36.3
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.769568,
#                   35.682195
#                 ],
#                 [
#                   139.769487,
#                   35.682051
#                 ],
#                 [
#                   139.769619,
#                   35.68197
#                 ],
#                 [
#                   139.769686,
#                   35.68209
#                 ],
#                 [
#                   139.769871,
#                   35.682021
#                 ],
#                 [
#                   139.770103,
#                   35.682394
#                 ],
#                 [
#                   139.770111,
#                   35.682391
#                 ],
#                 [
#                   139.770142,
#                   35.682453
#                 ],
#                 [
#                   139.76985,
#                   35.68255
#                 ],
#                 [
#                   139.769844,
#                   35.682539
#                 ],
#                 [
#                   139.769821,
#                   35.682548
#                 ],
#                 [
#                   139.769762,
#                   35.682446
#                 ],
#                 [
#                   139.769761,
#                   35.682446
#                 ],
#                 [
#                   139.769631,
#                   35.682222
#                 ],
#                 [
#                   139.769633,
#                   35.682221
#                 ],
#                 [
#                   139.769609,
#                   35.68218
#                 ],
#                 [
#                   139.769568,
#                   35.682195
#                 ]
#               ]
#             ],
#             &quot;type&quot;: &quot;Polygon&quot;
#           },
#           &quot;id&quot;: &quot;BLD_1620f11b-0687-4ba1-b599-41c5ad639eb3&quot;,
#           &quot;measuredHeight&quot;: 101.0
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               [
#                 [
#                   139.770707,
#                   35.680766
#                 ],
#                 [
#                   139.770633,
#                   35.680797
#                 ],
#                 [
#                   139.770633,
#                   35.680797
#                 ],
#                 [
#                   139.770613,
#                   35.680805
#                 ],
#                 [
#                   139.770592,
#                   35.680773
#                 ],
#                 [
#                   139.770671,
#                   35.680739
#                 ],
#                 [
#                   139.770672,
#                   35.680739
#                 ],
#                 [
#                   139.770686,

# %% [markdown]
# ### 選択範囲のデータを取得
#
# `.gdf` プロパティから選択範囲のデータ (`geopandas.GeoDataFrame`) を取得できます。

# %%
area.gdf
# Out:
#                                                id  measuredHeight  \
# 1526722  BLD_e2b1abb9-a3fa-4937-98a1-cb1b6c195069            46.0
# 1526759  BLD_fcc3ba97-3eb2-4148-b153-5c13ec3b966a            36.3
# 1526761  BLD_1620f11b-0687-4ba1-b599-41c5ad639eb3           101.0
# 1526763  BLD_45f1528c-75da-4702-a8c3-65325935bdfe            13.4
# 1526766  BLD_c56732aa-ac95-461f-a5b5-3c865dfd2d6f             4.9
# ...                                           ...             ...
# 1552813  BLD_a32e3f89-4698-421e-8a27-be7ab4966937            40.2
# 1552817  BLD_5cb1033f-98ba-4b5d-b5c6-f194db32a6c0           194.2
# 1552822  BLD_51a92ca9-69a6-4b46-a63c-b8700f50715c            55.1
# 1552824  BLD_84f3c9ec-efb0-49e7-a107-a532395debfa            37.8
# 1552825  BLD_42cda9fa-b8e2-41bd-8595-4c3ee32d5a64            17.0
#
#                                                   geometry
# 1526722  POLYGON ((139.76227 35.67986, 139.76223 35.679...
# 1526759  POLYGON ((139.77027 35.67809, 139.77031 35.678...
# 1526761  POLYGON ((139.76957 35.68220, 139.76949 35.682...
# 1526763  POLYGON ((139.77071 35.68077, 139.77063 35.680...
# 1526766  POLYGON ((139.76687 35.67833, 139.76687 35.678...
# ...                                                    ...
# 1552813  POLYGON ((139.76968 35.68674, 139.76962 35.686...
# 1552817  POLYGON ((139.77359 35.68674, 139.77335 35.687...
# 1552822  POLYGON ((139.77271 35.68675, 139.77271 35.686...
# 1552824  POLYGON ((139.77275 35.68457, 139.77298 35.684...
# 1552825  POLYGON ((139.77032 35.68501, 139.77032 35.685...
#
# [559 rows x 3 columns]

# %% [markdown]
# ### GeoJSON への変換
#
# `.to_geojson()` メソッドを使って選択範囲を GeoJSON 形式に変換できます。

# %%
data = area.to_geojson()

data[:300]
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "1526722", "type": "Feature", "properties": {"id": "BLD_e2b1abb9-a3fa-4937-98a1-cb1b6c195069", "measuredHeight": 46.0}, "geometry": {"type": "Polygon", "coordinates": [[[139.762267, 35.679862], [139.762228, 35.679746], [139.762602, 35.679663], [139.7'
